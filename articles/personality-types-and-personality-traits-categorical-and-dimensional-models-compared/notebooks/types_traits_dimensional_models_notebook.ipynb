# %% [markdown]
# # Personality Types and Personality Traits
# Synthetic-data notebook scaffold for categorical thresholds, dimensional traits, cluster summaries, boundary cases, and information loss.

# %%
from pathlib import Path
import pandas as pd
df = pd.read_csv(Path('..') / 'data' / 'synthetic_types_traits_dimensional_models.csv')
df.head()
