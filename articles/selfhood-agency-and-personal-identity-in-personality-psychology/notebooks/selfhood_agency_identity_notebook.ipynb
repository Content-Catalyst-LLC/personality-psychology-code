# %% [markdown]
# # Selfhood, Agency, and Personal Identity
# Synthetic-data notebook scaffold.

# %%
from pathlib import Path
import pandas as pd
df = pd.read_csv(Path('..') / 'data' / 'synthetic_selfhood_agency_identity.csv')
df.head()
