# %% [markdown]
# # Measurement in Personality Psychology
# Synthetic-data notebook scaffold for self-report, observer ratings, reliability, self–other agreement, response quality, and psychometrics.

# %%
from pathlib import Path
import pandas as pd
df = pd.read_csv(Path('..') / 'data' / 'synthetic_personality_measurement_data.csv')
df.head()
