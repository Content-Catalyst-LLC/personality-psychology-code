# %% [markdown]
# # Personality Development Across the Lifespan
# Synthetic longitudinal notebook scaffold.

# %%
from pathlib import Path
import pandas as pd
df = pd.read_csv(Path('..') / 'data' / 'synthetic_personality_lifespan.csv')
df.head()
