# %% [markdown]
# # The Person–Situation Debate
# Synthetic repeated-measures scaffold for behavioral consistency, aggregation, person–situation interactions, if–then signatures, and state distributions.

# %%
from pathlib import Path
import pandas as pd
df = pd.read_csv(Path('..') / 'data' / 'synthetic_person_situation_data.csv')
df.head()
