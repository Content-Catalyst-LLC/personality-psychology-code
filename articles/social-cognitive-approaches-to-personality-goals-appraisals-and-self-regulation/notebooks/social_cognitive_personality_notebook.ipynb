# %% [markdown]
# # Social-Cognitive Personality Processes
# Synthetic repeated-measures notebook scaffold.

# %%
from pathlib import Path
import pandas as pd
df = pd.read_csv(Path('..') / 'data' / 'synthetic_social_cognitive_personality.csv')
df.head()
