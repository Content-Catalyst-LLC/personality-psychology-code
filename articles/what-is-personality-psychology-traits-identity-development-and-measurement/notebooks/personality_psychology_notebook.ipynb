# %% [markdown]
# # What Is Personality Psychology?
# Synthetic scaffold for trait structure, identity-linked outcomes, person-situation interaction, measurement reliability, and responsible interpretation.

# %%
from pathlib import Path
import pandas as pd
df = pd.read_csv(Path('..') / 'data' / 'synthetic_personality_items.csv')
state_df = pd.read_csv(Path('..') / 'data' / 'synthetic_person_situation_observations.csv')
df.head()
