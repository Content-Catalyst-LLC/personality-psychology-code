# %% [markdown]
# # Self-Concept, Self-Esteem, and Self-Knowledge
# Synthetic-data notebook scaffold.

# %%
from pathlib import Path
import pandas as pd
df = pd.read_csv(Path('..') / 'data' / 'synthetic_self_concept_self_esteem_self_knowledge.csv')
df.head()
