# %% [markdown]
# # Trait Hierarchies, Facets, and Personality Architecture
# Synthetic item-level scaffold for broad domains, facets, reliability, bandwidth-fidelity comparison, and hierarchical prediction.

# %%
from pathlib import Path
import pandas as pd
df = pd.read_csv(Path('..') / 'data' / 'synthetic_hierarchical_trait_items.csv')
df.head()
