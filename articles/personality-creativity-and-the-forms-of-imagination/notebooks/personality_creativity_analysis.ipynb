# %% [markdown]
# # Personality, Creativity, and the Forms of Imagination
#
# This notebook scaffold mirrors the Python workflow and supports transparent exploratory analysis of the synthetic companion dataset.

# %%
from pathlib import Path
import pandas as pd

article_dir = Path.cwd()
data_path = article_dir / 'data' / 'synthetic_personality_creativity.csv'
df = pd.read_csv(data_path)
df.head()

# %%
numeric_cols = ['openness', 'intellect', 'conscientiousness', 'extraversion', 'agreeableness', 'neuroticism', 'persistence', 'social_support', 'divergent_thinking', 'creative_achievement', 'everyday_creativity']
df[numeric_cols].describe().T

# %% [markdown]
# ## Interpretation
#
# The analysis separates divergent thinking, creative achievement, and everyday creativity to avoid reducing creativity to a single undifferentiated outcome.
