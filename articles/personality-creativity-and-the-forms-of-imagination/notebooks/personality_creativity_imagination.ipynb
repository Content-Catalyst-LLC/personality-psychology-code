# %% [markdown]
# # Personality, Creativity, and the Forms of Imagination
#
# This notebook scaffold demonstrates a reproducible workflow for the synthetic personality-creativity dataset.

# %%
from pathlib import Path
import pandas as pd

root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
df = pd.read_csv(root / 'data' / 'synthetic_personality_creativity.csv')
df.head()

# %%
df.groupby('domain')[['divergent_thinking', 'creative_achievement', 'everyday_creativity']].mean().round(2)
