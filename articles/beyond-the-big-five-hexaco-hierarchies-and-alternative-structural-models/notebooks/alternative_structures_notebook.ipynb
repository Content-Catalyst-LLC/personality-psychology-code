# %% [markdown]
# # Beyond the Big Five: Alternative Structural Models
# Synthetic scaffold for five-factor/six-factor comparison, HEXACO-style scoring, hierarchy, facets, and model comparison.

# %%
from pathlib import Path
import pandas as pd
df = pd.read_csv(Path('..') / 'data' / 'synthetic_alternative_structure_items.csv')
df.head()
