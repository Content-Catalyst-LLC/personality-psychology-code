# %% [markdown]
# # Temperament and Early Personality Foundations
# Synthetic longitudinal scaffold for early reactivity, effortful control, caregiving transaction, environmental moderation, and later personality outcomes.

# %%
from pathlib import Path
import pandas as pd
df = pd.read_csv(Path('..') / 'data' / 'synthetic_temperament_personality_longitudinal.csv')
df.head()
