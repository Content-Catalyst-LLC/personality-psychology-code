# %% [markdown]
# # History of Personality Psychology
# Synthetic scaffold for characterology-to-personality-science workflows: dimensions, reliability, stability, person-situation interaction, and measurement cautions.

# %%
from pathlib import Path
import pandas as pd
df = pd.read_csv(Path('..') / 'data' / 'synthetic_personality_history_items.csv')
df.head()
