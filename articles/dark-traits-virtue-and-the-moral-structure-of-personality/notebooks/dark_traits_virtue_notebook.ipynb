# %% [markdown]
# # Dark Traits, Virtue, and Moral Personality Structure
# Synthetic-data notebook scaffold.

# %%
from pathlib import Path
import pandas as pd
df = pd.read_csv(Path('..') / 'data' / 'synthetic_dark_traits_virtue_personality.csv')
df.head()
