# %% [markdown]
# # Trait Stability, Disposition, and Individual Difference
# Synthetic scaffold for trait scoring, state aggregation, reliability, person-situation variance, and density-distribution approaches.

# %%
from pathlib import Path
import pandas as pd
trait_df = pd.read_csv(Path('..') / 'data' / 'synthetic_trait_items.csv')
state_df = pd.read_csv(Path('..') / 'data' / 'synthetic_state_observations.csv')
trait_df.head()
