# %% [markdown]
# # Motivation, Goals, and the Architecture of Desire
# Synthetic-data notebook scaffold.

# %%
from pathlib import Path
import pandas as pd
df = pd.read_csv(Path('..') / 'data' / 'synthetic_motivation_goals_desire.csv')
df.head()
