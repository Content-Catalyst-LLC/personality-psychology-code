# %% [markdown]
# # The Lexical Hypothesis and Trait Structure
# Synthetic scaffold for lexical descriptor ratings, covariance, dimensionality reduction, descriptor-cluster reliability, and five/six-factor comparison.

# %%
from pathlib import Path
import pandas as pd
df = pd.read_csv(Path('..') / 'data' / 'synthetic_lexical_descriptors.csv')
df.head()
