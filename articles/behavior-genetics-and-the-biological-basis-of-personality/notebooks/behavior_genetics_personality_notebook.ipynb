# %% [markdown]
# # Behavior Genetics and Personality
# Synthetic twin-style scaffold for heritability, rough ACE estimates, environmental moderation, and responsible interpretation.

# %%
from pathlib import Path
import pandas as pd
df = pd.read_csv(Path('..') / 'data' / 'synthetic_personality_twin_data.csv')
df.head()
