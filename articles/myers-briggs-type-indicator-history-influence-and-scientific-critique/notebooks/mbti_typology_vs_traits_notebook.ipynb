# %% [markdown]
# # MBTI Typology vs. Dimensional Traits
# Synthetic-data notebook scaffold for threshold effects, type-code construction, boundary cases, and information loss.

# %%
from pathlib import Path
import pandas as pd
df = pd.read_csv(Path('..') / 'data' / 'synthetic_mbti_typology_vs_traits.csv')
df.head()
